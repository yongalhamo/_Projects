# %%
import pandas as pd
import urllib
import json
import googlemaps

# %%
df= pd.read_csv("filtered_data")

# %%
mta_stations = list(df['STATION'].unique())
len(mta_stations)
# Out:
# 50

# %%
stations_zip = pd.DataFrame(columns = ['STATION', 'ZIP'])

# %%
zips = pd.DataFrame(data=None)
base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'
api_key = 'AIzaSyAz-bqF7JsezNqm1ISHphbiKL4xXJ7kQ7Q'
scontext = None

# %%
from collections import defaultdict
unique_geocodes = defaultdict(str)
download=False

if download==True:
    for address in ny_stations:
        geocode = gmaps.geocode(address)
        unique_geocodes[address] = geocode

# %%
zipcodes = []
stations = []

for station in mta_stations:
        search_criteria = {'address': station + ' station, New York, NY',
                           'key' : api_key
                           }
        u= urllib.parse.urlencode(search_criteria)
        url= base_url + u
        data = urllib.request.urlopen(urllib.request.Request(url)).read().decode('utf-8')
        js = json.loads(data)
        dicts = js['results'][0]['address_components']
        if dicts[len(dicts) - 1]['types'] == ['postal_code']:
                zipcodes=(dicts[len(dicts)- 1]['long_name'])
                zips = zips.append(pd.Series((station, zipcodes)), ignore_index=True)

# %%
zipcodes = []
stations = []

for station in mta_stations:
        search_criteria = {'address': station + ' station, New York, NY',
                           'key' : api_key
                           }
        u= urllib.parse.urlencode(search_criteria)
        url= base_url + u
        data = urllib.request.urlopen(urllib.request.Request(url)).read().decode('utf-8')
        js = json.loads(data)
        dicts = js['results'][0]['address_components']
        if dicts[len(dicts) - 1]['types'] == ['postal_code']:
                zipcodes=(dicts[len(dicts)- 1]['long_name'])
                

        zips = zips.append(pd.Series((station, zipcodes)), ignore_index=True)
        print(zips)
# Out:
#                 0      1
# 0  34 ST-PENN STA  10001
#                  0      1
# 0   34 ST-PENN STA  10001
# 1  GRD CNTRL-42 ST  10017
#                  0      1
# 0   34 ST-PENN STA  10001
# 1  GRD CNTRL-42 ST  10017
# 2  34 ST-HERALD SQ  10017
#                  0      1
# 0   34 ST-PENN STA  10001
# 1  GRD CNTRL-42 ST  10017
# 2  34 ST-HERALD SQ  10017
# 3            23 ST  10011
#                  0      1
# 0   34 ST-PENN STA  10001
# 1  GRD CNTRL-42 ST  10017
# 2  34 ST-HERALD SQ  10017
# 3            23 ST  10011
# 4   14 ST-UNION SQ  10003
#                  0      1
# 0   34 ST-PENN STA  10001
# 1  GRD CNTRL-42 ST  10017
# 2  34 ST-HERALD SQ  10017
# 3            23 ST  10011
# 4   14 ST-UNION SQ  10003
# 5   TIMES SQ-42 ST  10036
#                  0      1
# 0   34 ST-PENN STA  10001
# 1  GRD CNTRL-42 ST  10017
# 2  34 ST-HERALD SQ  10017
# 3            23 ST  10011
# 4   14 ST-UNION SQ  10003
# 5   TIMES SQ-42 ST  10036
# 6     PATH NEW WTC  10007
# ...

# %%
zips.rename(columns = {0: 'station', 1: 'zip_code'},
           inplace= True)
zips.head(10)
# Out:
#            station zip_code
# 0   34 ST-PENN STA    10001
# 1  GRD CNTRL-42 ST    10017
# 2  34 ST-HERALD SQ    10017
# 3            23 ST    10011
# 4   14 ST-UNION SQ    10003
# 5   TIMES SQ-42 ST    10036
# 6     PATH NEW WTC    10007
# 7  42 ST-PORT AUTH    10007
# 8        FULTON ST    10038
# 9            86 ST    10028

# %%
zips.zip_code.value_counts()
# Out:
# 07302    3
# 10007    3
# 10011    3
# 10023    3
# 10017    2
# 10019    2
# 10001    2
# 10035    2
# 11201    2
# 10038    2
# 10018    2
# 10106    2
# 10021    1
# 07114    1
# 07310    1
# 10012    1
# 10020    1
# 10036    1
# 11220    1
# 07306    1
# 10013    1
# 10022    1
# 11354    1
# 11372    1
# 10014    1
# 10004    1
# 10002    1
# 10028    1
# 10025    1
# 11217    1
# 11226    1
# 10075    1
# 10003    1
# 10031    1
# Name: zip_code, dtype: int64

# %%
zips.to_csv("Zip_code")
